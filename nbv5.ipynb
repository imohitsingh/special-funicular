# %%
import json

import numpy as np
from nltk.stem import WordNetLemmatizer
import random
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD

# Load intents from JSON
def load_intents(filename):
    with open(filename, 'r') as file:
        intents = json.load(file)
    return intents['intents']


def preprocess_intents(intents):
    words = []
    classes = []
    documents = []
    for intent in intents:
        for pattern in intent['patterns']:
            # Tokenize each pattern and add words to the vocabulary
            w = nltk.word_tokenize(pattern)
            words.extend(w)
            # Add pattern words to words list if not already present
            documents.append((w, intent['tag']))
        # Add intent tag to classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
    # Lemmatize words and remove duplicates
    words = [WordNetLemmatizer().lemmatize(w.lower()) for w in words if w not in ['?', '.', '!']]
    words = sorted(list(set(words)))
    # Sort classes
    classes = sorted(list(set(classes)))
    return words, classes, documents


# Create training data
def create_training_data(words, classes, documents):
    training = []
    output_empty = [0] * len(classes)
    for doc in documents:
        bag = []
        pattern_words = doc[0]
        pattern_words = [WordNetLemmatizer().lemmatize(word.lower()) for word in pattern_words]
        for w in words:
            bag.append(1) if w in pattern_words else bag.append(0)

        output_row = list(output_empty)
        output_row[classes.index(doc[1])] = 1

        training.append([bag, output_row])

    random.shuffle(training)
    train_X = []
    train_Y = []
    for features, label in training:
        train_X.append(features)
        train_Y.append(label)
    return train_X, train_Y


# Modify the create_model function
def create_model(input_size, output_size):
    model = Sequential([
        Dense(128, input_shape=(input_size,), activation='relu'),
        Dropout(0.5),
        Dense(64, activation='relu'),
        Dropout(0.5),
        Dense(output_size, activation='softmax')
    ])
    # Use the new version of SGD optimizer
    sgd = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
    model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
    return model


# Main function
def main():
    intents = load_intents('intents2.json')
    words, classes, documents = preprocess_intents(intents)
    train_X, train_Y = create_training_data(words, classes, documents)
    input_size = len(train_X[0])
    output_size = len(train_Y[0])

    model = create_model(input_size, output_size)
    model.fit(np.array(train_X), np.array(train_Y), epochs=200, batch_size=5, verbose=1)

if __name__ == "__main__":
    main()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Epoch 1/200
# 6/6 [==============================] - 0s 589us/step - loss: 2.2718 - accuracy: 0.1333
# Epoch 2/200
# 6/6 [==============================] - 0s 490us/step - loss: 2.2280 - accuracy: 0.2000
# Epoch 3/200
# 6/6 [==============================] - 0s 469us/step - loss: 2.0995 - accuracy: 0.4000
# Epoch 4/200
# 6/6 [==============================] - 0s 434us/step - loss: 1.9425 - accuracy: 0.4000
# Epoch 5/200
# 6/6 [==============================] - 0s 486us/step - loss: 1.9034 - accuracy: 0.4000
# Epoch 6/200
# 6/6 [==============================] - 0s 566us/step - loss: 1.7455 - accuracy: 0.4333
# Epoch 7/200
# 6/6 [==============================] - 0s 666us/step - loss: 1.6752 - accuracy: 0.4333
# Epoch 8/200
# 6/6 [==============================] - 0s 651us/step - loss: 1.6198 - accuracy: 0.4000
# Epoch 9/200
# 6/6 [==============================] - 0s 550us/step - loss: 1.6536 - accuracy: 0.4667
# Epoch 10/200
# 6/6 [==============================] - 0s 783us/step - loss: 1.5100 - accuracy: 0.5667
# Epoch 11/200
# 6/6 [==============================] - 0s 576us/step - loss: 1.3715 - accuracy: 0.5333
# Epoch 12/200
# 6/6 [==============================] - 0s 548us/step - loss: 1.3919 - accuracy: 0.5333
# Epoch 13/200
# 6/6 [==============================] - 0s 551us/step - loss: 1.2358 - accuracy: 0.6333
# Epoch 14/200
# 6/6 [==============================] - 0s 691us/step - loss: 1.2681 - accuracy: 0.6000
# Epoch 15/200
# 6/6 [==============================] - 0s 546us/step - loss: 1.2451 - accuracy: 0.6333
# Epoch 16/200
# 6/6 [==============================] - 0s 523us/step - loss: 1.0847 - accuracy: 0.7667
# Epoch 17/200
# 6/6 [==============================] - 0s 480us/step - loss: 1.0901 - accuracy: 0.7000
# Epoch 18/200
# 6/6 [==============================] - 0s 596us/step - loss: 0.9509 - accuracy: 0.6667
# Epoch 19/200
# 6/6 [==============================] - 0s 473us/step - loss: 1.0786 - accuracy: 0.5667
# Epoch 20/200
# 6/6 [==============================] - 0s 484us/step - loss: 1.0240 - accuracy: 0.6000
# Epoch 21/200
# 6/6 [==============================] - 0s 529us/step - loss: 0.9092 - accuracy: 0.7000
# Epoch 22/200
# 6/6 [==============================] - 0s 519us/step - loss: 0.7899 - accuracy: 0.7667
# Epoch 23/200
# 6/6 [==============================] - 0s 540us/step - loss: 0.9247 - accuracy: 0.6333
# Epoch 24/200
# 6/6 [==============================] - 0s 509us/step - loss: 0.6206 - accuracy: 0.8000
# Epoch 25/200
# 6/6 [==============================] - 0s 474us/step - loss: 0.7674 - accuracy: 0.8000
# Epoch 26/200
# 6/6 [==============================] - 0s 496us/step - loss: 0.5467 - accuracy: 0.9333
# Epoch 27/200
# 6/6 [==============================] - 0s 531us/step - loss: 0.5820 - accuracy: 0.8333
# Epoch 28/200
# 6/6 [==============================] - 0s 527us/step - loss: 0.5220 - accuracy: 0.9000
# Epoch 29/200
# 6/6 [==============================] - 0s 551us/step - loss: 0.4350 - accuracy: 0.8667
# Epoch 30/200
# 6/6 [==============================] - 0s 582us/step - loss: 0.5795 - accuracy: 0.8000
# Epoch 31/200
# 6/6 [==============================] - 0s 616us/step - loss: 0.7750 - accuracy: 0.7000
# Epoch 32/200
# 6/6 [==============================] - 0s 580us/step - loss: 0.4987 - accuracy: 0.9667
# Epoch 33/200
# 6/6 [==============================] - 0s 490us/step - loss: 0.4715 - accuracy: 0.8667
# Epoch 34/200
# 6/6 [==============================] - 0s 485us/step - loss: 0.4886 - accuracy: 0.8333
# Epoch 35/200
# 6/6 [==============================] - 0s 577us/step - loss: 0.4186 - accuracy: 0.9000
# Epoch 36/200
# 6/6 [==============================] - 0s 468us/step - loss: 0.3993 - accuracy: 0.9333
# Epoch 37/200
# 6/6 [==============================] - 0s 495us/step - loss: 0.3833 - accuracy: 0.8333
# Epoch 38/200
# 6/6 [==============================] - 0s 490us/step - loss: 0.3608 - accuracy: 0.9000
# Epoch 39/200
# 6/6 [==============================] - 0s 542us/step - loss: 0.3525 - accuracy: 0.8667
# Epoch 40/200
# 6/6 [==============================] - 0s 466us/step - loss: 0.3292 - accuracy: 0.9333
# Epoch 41/200
# 6/6 [==============================] - 0s 490us/step - loss: 0.3515 - accuracy: 0.9000
# Epoch 42/200
# 6/6 [==============================] - 0s 477us/step - loss: 0.3068 - accuracy: 0.9667
# Epoch 43/200
# 6/6 [==============================] - 0s 500us/step - loss: 0.3177 - accuracy: 0.9667
# Epoch 44/200
# 6/6 [==============================] - 0s 712us/step - loss: 0.3441 - accuracy: 0.8667
# Epoch 45/200
# 6/6 [==============================] - 0s 627us/step - loss: 0.3676 - accuracy: 0.8667
# Epoch 46/200
# 6/6 [==============================] - 0s 540us/step - loss: 0.1859 - accuracy: 0.9667
# Epoch 47/200
# 6/6 [==============================] - 0s 642us/step - loss: 0.5563 - accuracy: 0.8000
# Epoch 48/200
# 6/6 [==============================] - 0s 530us/step - loss: 0.1897 - accuracy: 0.9667
# Epoch 49/200
# 6/6 [==============================] - 0s 501us/step - loss: 0.3188 - accuracy: 0.9000
# Epoch 50/200
# 6/6 [==============================] - 0s 498us/step - loss: 0.3614 - accuracy: 0.9000
# Epoch 51/200
# 6/6 [==============================] - 0s 681us/step - loss: 0.1621 - accuracy: 0.9667
# Epoch 52/200
# 6/6 [==============================] - 0s 500us/step - loss: 0.1943 - accuracy: 1.0000
# Epoch 53/200
# 6/6 [==============================] - 0s 519us/step - loss: 0.1494 - accuracy: 0.9667
# Epoch 54/200
# 6/6 [==============================] - 0s 515us/step - loss: 0.1843 - accuracy: 1.0000
# Epoch 55/200
# 6/6 [==============================] - 0s 929us/step - loss: 0.1212 - accuracy: 0.9667
# Epoch 56/200
# 6/6 [==============================] - 0s 497us/step - loss: 0.2792 - accuracy: 0.9333
# Epoch 57/200
# 6/6 [==============================] - 0s 498us/step - loss: 0.1326 - accuracy: 1.0000
# Epoch 58/200
# 6/6 [==============================] - 0s 477us/step - loss: 0.2785 - accuracy: 0.9000
# Epoch 59/200
# 6/6 [==============================] - 0s 549us/step - loss: 0.1634 - accuracy: 0.9667
# Epoch 60/200
# 6/6 [==============================] - 0s 506us/step - loss: 0.1487 - accuracy: 1.0000
# Epoch 61/200
# 6/6 [==============================] - 0s 456us/step - loss: 0.1192 - accuracy: 0.9667
# Epoch 62/200
# 6/6 [==============================] - 0s 465us/step - loss: 0.1696 - accuracy: 0.9667
# Epoch 63/200
# 6/6 [==============================] - 0s 521us/step - loss: 0.2487 - accuracy: 0.9000
# Epoch 64/200
# 6/6 [==============================] - 0s 473us/step - loss: 0.2497 - accuracy: 0.9000
# Epoch 65/200
# 6/6 [==============================] - 0s 460us/step - loss: 0.2488 - accuracy: 0.8667
# Epoch 66/200
# 6/6 [==============================] - 0s 484us/step - loss: 0.3685 - accuracy: 0.9000
# Epoch 67/200
# 6/6 [==============================] - 0s 517us/step - loss: 0.3138 - accuracy: 0.8667
# Epoch 68/200
# 6/6 [==============================] - 0s 591us/step - loss: 0.1529 - accuracy: 1.0000
# Epoch 69/200
# 6/6 [==============================] - 0s 496us/step - loss: 0.1502 - accuracy: 0.9333
# Epoch 70/200
# 6/6 [==============================] - 0s 507us/step - loss: 0.1313 - accuracy: 1.0000
# Epoch 71/200
# 6/6 [==============================] - 0s 472us/step - loss: 0.1478 - accuracy: 1.0000
# Epoch 72/200
# 6/6 [==============================] - 0s 568us/step - loss: 0.2517 - accuracy: 0.9000
# Epoch 73/200
# 6/6 [==============================] - 0s 494us/step - loss: 0.1513 - accuracy: 1.0000
# Epoch 74/200
# 6/6 [==============================] - 0s 613us/step - loss: 0.1623 - accuracy: 0.9333
# Epoch 75/200
# 6/6 [==============================] - 0s 581us/step - loss: 0.1404 - accuracy: 0.9333
# Epoch 76/200
# 6/6 [==============================] - 0s 573us/step - loss: 0.0782 - accuracy: 1.0000
# Epoch 77/200
# 6/6 [==============================] - 0s 593us/step - loss: 0.1771 - accuracy: 0.9333
# Epoch 78/200
# 6/6 [==============================] - 0s 474us/step - loss: 0.0703 - accuracy: 1.0000
# Epoch 79/200
# 6/6 [==============================] - 0s 481us/step - loss: 0.0716 - accuracy: 1.0000
# Epoch 80/200
# 6/6 [==============================] - 0s 463us/step - loss: 0.1466 - accuracy: 0.9667
# Epoch 81/200
# 6/6 [==============================] - 0s 493us/step - loss: 0.0745 - accuracy: 1.0000
# Epoch 82/200
# 6/6 [==============================] - 0s 472us/step - loss: 0.0940 - accuracy: 1.0000
# Epoch 83/200
# 6/6 [==============================] - 0s 484us/step - loss: 0.0883 - accuracy: 0.9667
# Epoch 84/200
# 6/6 [==============================] - 0s 442us/step - loss: 0.1285 - accuracy: 0.9667
# Epoch 85/200
# 6/6 [==============================] - 0s 461us/step - loss: 0.1020 - accuracy: 1.0000
# Epoch 86/200
# 6/6 [==============================] - 0s 463us/step - loss: 0.1517 - accuracy: 0.9333
# Epoch 87/200
# 6/6 [==============================] - 0s 475us/step - loss: 0.1335 - accuracy: 0.9667
# Epoch 88/200
# 6/6 [==============================] - 0s 445us/step - loss: 0.1923 - accuracy: 0.9333
# Epoch 89/200
# 6/6 [==============================] - 0s 452us/step - loss: 0.1289 - accuracy: 0.9667
# Epoch 90/200
# 6/6 [==============================] - 0s 448us/step - loss: 0.1459 - accuracy: 0.9667
# Epoch 91/200
# 6/6 [==============================] - 0s 479us/step - loss: 0.0499 - accuracy: 1.0000
# Epoch 92/200
# 6/6 [==============================] - 0s 467us/step - loss: 0.0551 - accuracy: 1.0000
# Epoch 93/200
# 6/6 [==============================] - 0s 506us/step - loss: 0.0745 - accuracy: 1.0000
# Epoch 94/200
# 6/6 [==============================] - 0s 466us/step - loss: 0.0741 - accuracy: 0.9667
# Epoch 95/200
# 6/6 [==============================] - 0s 438us/step - loss: 0.1104 - accuracy: 0.9667
# Epoch 96/200
# 6/6 [==============================] - 0s 502us/step - loss: 0.1025 - accuracy: 0.9667
# Epoch 97/200
# 6/6 [==============================] - 0s 420us/step - loss: 0.0702 - accuracy: 0.9667
# Epoch 98/200
# 6/6 [==============================] - 0s 476us/step - loss: 0.1597 - accuracy: 0.9000
# Epoch 99/200
# 6/6 [==============================] - 0s 468us/step - loss: 0.1503 - accuracy: 0.9333
# Epoch 100/200
# 6/6 [==============================] - 0s 480us/step - loss: 0.0741 - accuracy: 0.9667
# Epoch 101/200
# 6/6 [==============================] - 0s 522us/step - loss: 0.0497 - accuracy: 1.0000
# Epoch 102/200
# 6/6 [==============================] - 0s 450us/step - loss: 0.0445 - accuracy: 1.0000
# Epoch 103/200
# 6/6 [==============================] - 0s 506us/step - loss: 0.0965 - accuracy: 0.9667
# Epoch 104/200
# 6/6 [==============================] - 0s 474us/step - loss: 0.1589 - accuracy: 0.9333
# Epoch 105/200
# 6/6 [==============================] - 0s 535us/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 106/200
# 6/6 [==============================] - 0s 494us/step - loss: 0.0578 - accuracy: 1.0000
# Epoch 107/200
# 6/6 [==============================] - 0s 444us/step - loss: 0.0877 - accuracy: 1.0000
# Epoch 108/200
# 6/6 [==============================] - 0s 474us/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 109/200
# 6/6 [==============================] - 0s 426us/step - loss: 0.0622 - accuracy: 0.9667
# Epoch 110/200
# 6/6 [==============================] - 0s 435us/step - loss: 0.0447 - accuracy: 1.0000
# Epoch 111/200
# 6/6 [==============================] - 0s 466us/step - loss: 0.1840 - accuracy: 0.9000
# Epoch 112/200
# 6/6 [==============================] - 0s 433us/step - loss: 0.1414 - accuracy: 0.9667
# Epoch 113/200
# 6/6 [==============================] - 0s 452us/step - loss: 0.0416 - accuracy: 1.0000
# Epoch 114/200
# 6/6 [==============================] - 0s 476us/step - loss: 0.0585 - accuracy: 1.0000
# Epoch 115/200
# 6/6 [==============================] - 0s 463us/step - loss: 0.1617 - accuracy: 0.9000
# Epoch 116/200
# 6/6 [==============================] - 0s 622us/step - loss: 0.0513 - accuracy: 1.0000
# Epoch 117/200
# 6/6 [==============================] - 0s 473us/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 118/200
# 6/6 [==============================] - 0s 448us/step - loss: 0.0429 - accuracy: 0.9667
# Epoch 119/200
# 6/6 [==============================] - 0s 463us/step - loss: 0.0836 - accuracy: 0.9667
# Epoch 120/200
# 6/6 [==============================] - 0s 486us/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 121/200
# 6/6 [==============================] - 0s 592us/step - loss: 0.0396 - accuracy: 1.0000
# Epoch 122/200
# 6/6 [==============================] - 0s 509us/step - loss: 0.1102 - accuracy: 1.0000
# Epoch 123/200
# 6/6 [==============================] - 0s 501us/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 124/200
# 6/6 [==============================] - 0s 497us/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 125/200
# 6/6 [==============================] - 0s 462us/step - loss: 0.0684 - accuracy: 0.9667
# Epoch 126/200
# 6/6 [==============================] - 0s 464us/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 127/200
# 6/6 [==============================] - 0s 462us/step - loss: 0.1920 - accuracy: 0.9333
# Epoch 128/200
# 6/6 [==============================] - 0s 455us/step - loss: 0.0624 - accuracy: 0.9667
# Epoch 129/200
# 6/6 [==============================] - 0s 432us/step - loss: 0.2255 - accuracy: 0.9333
# Epoch 130/200
# 6/6 [==============================] - 0s 460us/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 131/200
# 6/6 [==============================] - 0s 556us/step - loss: 0.1675 - accuracy: 0.9333
# Epoch 132/200
# 6/6 [==============================] - 0s 459us/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 133/200
# 6/6 [==============================] - 0s 482us/step - loss: 0.0703 - accuracy: 1.0000
# Epoch 134/200
# 6/6 [==============================] - 0s 452us/step - loss: 0.1116 - accuracy: 0.9667
# Epoch 135/200
# 6/6 [==============================] - 0s 462us/step - loss: 0.0659 - accuracy: 0.9667
# Epoch 136/200
# 6/6 [==============================] - 0s 436us/step - loss: 0.0530 - accuracy: 0.9667
# Epoch 137/200
# 6/6 [==============================] - 0s 469us/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 138/200
# 6/6 [==============================] - 0s 456us/step - loss: 0.0543 - accuracy: 0.9667
# Epoch 139/200
# 6/6 [==============================] - 0s 452us/step - loss: 0.1009 - accuracy: 0.9667
# Epoch 140/200
# 6/6 [==============================] - 0s 450us/step - loss: 0.0436 - accuracy: 1.0000
# Epoch 141/200
# 6/6 [==============================] - 0s 613us/step - loss: 0.0566 - accuracy: 1.0000
# Epoch 142/200
# 6/6 [==============================] - 0s 455us/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 143/200
# 6/6 [==============================] - 0s 454us/step - loss: 0.0638 - accuracy: 1.0000
# Epoch 144/200
# 6/6 [==============================] - 0s 439us/step - loss: 0.1043 - accuracy: 0.9667
# Epoch 145/200
# 6/6 [==============================] - 0s 460us/step - loss: 0.0727 - accuracy: 0.9667
# Epoch 146/200
# 6/6 [==============================] - 0s 502us/step - loss: 0.0674 - accuracy: 0.9667
# Epoch 147/200
# 6/6 [==============================] - 0s 440us/step - loss: 0.0500 - accuracy: 1.0000
# Epoch 148/200
# 6/6 [==============================] - 0s 455us/step - loss: 0.0514 - accuracy: 1.0000
# Epoch 149/200
# 6/6 [==============================] - 0s 459us/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 150/200
# 6/6 [==============================] - 0s 444us/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 151/200
# 6/6 [==============================] - 0s 558us/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 152/200
# 6/6 [==============================] - 0s 503us/step - loss: 0.0390 - accuracy: 1.0000
# Epoch 153/200
# 6/6 [==============================] - 0s 474us/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 154/200
# 6/6 [==============================] - 0s 460us/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 155/200
# 6/6 [==============================] - 0s 468us/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 156/200
# 6/6 [==============================] - 0s 522us/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 157/200
# 6/6 [==============================] - 0s 480us/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 158/200
# 6/6 [==============================] - 0s 456us/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 159/200
# 6/6 [==============================] - 0s 474us/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 160/200
# 6/6 [==============================] - 0s 474us/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 161/200
# 6/6 [==============================] - 0s 489us/step - loss: 0.0548 - accuracy: 0.9667
# Epoch 162/200
# 6/6 [==============================] - 0s 494us/step - loss: 0.0658 - accuracy: 1.0000
# Epoch 163/200
# 6/6 [==============================] - 0s 437us/step - loss: 0.0686 - accuracy: 1.0000
# Epoch 164/200
# 6/6 [==============================] - 0s 497us/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 165/200
# 6/6 [==============================] - 0s 461us/step - loss: 0.0437 - accuracy: 1.0000
# Epoch 166/200
# 6/6 [==============================] - 0s 430us/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 167/200
# 6/6 [==============================] - 0s 439us/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 168/200
# 6/6 [==============================] - 0s 447us/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 169/200
# 6/6 [==============================] - 0s 478us/step - loss: 0.0537 - accuracy: 1.0000
# Epoch 170/200
# 6/6 [==============================] - 0s 461us/step - loss: 0.0775 - accuracy: 0.9667
# Epoch 171/200
# 6/6 [==============================] - 0s 513us/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 172/200
# 6/6 [==============================] - 0s 478us/step - loss: 0.0417 - accuracy: 1.0000
# Epoch 173/200
# 6/6 [==============================] - 0s 434us/step - loss: 0.0512 - accuracy: 0.9667
# Epoch 174/200
# 6/6 [==============================] - 0s 441us/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 175/200
# 6/6 [==============================] - 0s 477us/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 176/200
# 6/6 [==============================] - 0s 438us/step - loss: 0.0396 - accuracy: 1.0000
# Epoch 177/200
# 6/6 [==============================] - 0s 445us/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 178/200
# 6/6 [==============================] - 0s 456us/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 179/200
# 6/6 [==============================] - 0s 437us/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 180/200
# 6/6 [==============================] - 0s 504us/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 181/200
# 6/6 [==============================] - 0s 443us/step - loss: 0.1141 - accuracy: 0.9667
# Epoch 182/200
# 6/6 [==============================] - 0s 453us/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 183/200
# 6/6 [==============================] - 0s 457us/step - loss: 0.1338 - accuracy: 0.9667
# Epoch 184/200
# 6/6 [==============================] - 0s 446us/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 185/200
# 6/6 [==============================] - 0s 434us/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 186/200
# 6/6 [==============================] - 0s 438us/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 187/200
# 6/6 [==============================] - 0s 445us/step - loss: 0.0536 - accuracy: 0.9667
# Epoch 188/200
# 6/6 [==============================] - 0s 474us/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 189/200
# 6/6 [==============================] - 0s 476us/step - loss: 0.0429 - accuracy: 1.0000
# Epoch 190/200
# 6/6 [==============================] - 0s 465us/step - loss: 0.0629 - accuracy: 0.9667
# Epoch 191/200
# 6/6 [==============================] - 0s 571us/step - loss: 0.0724 - accuracy: 0.9667
# Epoch 192/200
# 6/6 [==============================] - 0s 475us/step - loss: 0.1132 - accuracy: 0.9667
# Epoch 193/200
# 6/6 [==============================] - 0s 454us/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 194/200
# 6/6 [==============================] - 0s 457us/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 195/200
# 6/6 [==============================] - 0s 463us/step - loss: 0.0516 - accuracy: 1.0000
# Epoch 196/200
# 6/6 [==============================] - 0s 457us/step - loss: 0.0519 - accuracy: 1.0000
# Epoch 197/200
# 6/6 [==============================] - 0s 463us/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 198/200
# 6/6 [==============================] - 0s 435us/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 199/200
# 6/6 [==============================] - 0s 453us/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 200/200
# 6/6 [==============================] - 0s 452us/step - loss: 0.0185 - accuracy: 1.0000

# %%
#use case 1 - get headlines
import requests

def get_headlines():
    
    api_url = "https://newsapi.org/v2/top-headlines"
    
    
    api_key = '05a64f048db44f29b5d7d30402cac91a'
    
    #parameters for the API request
    parameters = {
        "apiKey": api_key,
        "country": "us",  
        "pageSize": 5    
    }
    
    try:
        # Sending a get request
        response = requests.get(api_url, params=parameters)
        
        # Checking if the request was successful (status code 200)
        if response.status_code == 200:
            # Parsing the JSON response
            data = response.json()
            
            # Extracting the headlines from the response
            headlines = [article['title'] for article in data['articles']]
            
            # Printing the headlines
            for headline in headlines:
                print(headline)
                
        else:
            print("Failed to fetch headlines. Status code:", response.status_code)
    
    except Exception as e:
        print("An error occurred:", e)

#Example usage:
#get_headlines()

# %%
#use case 2 - search news by topic
import requests
import re
"""
def extract_topic(user_input):
    # Define regular expression patterns to match phrases like "Find news about [topic]"
    patterns = [
        r"Find news about (.*)$",
        r"Show me articles on (.*)$"
    ]
    
    # Iterate over patterns and attempt to match them with user input
    for pattern in patterns:
        match = re.search(pattern, user_input)
        if match:
            # Extract the topic from the matched pattern
            topic = match.group(1)
            print("Extracted topic:", topic)
            return topic
    
    # If no pattern matches, return None
    return None
"""

def search_news_by_topic(topic):
   
    api_key = '05a64f048db44f29b5d7d30402cac91a'
    url = f'https://newsapi.org/v2/everything?q={topic}&apiKey={api_key}'
    
    try:
        response = requests.get(url)
        data = response.json()
        
        # Extracting relevant information from the response, such as article titles, descriptions, sources, etc.
        articles = data['articles']
        
        # Printing the  information
        for article in articles[:5]:
            title = article['title']
            description = article['description']
            source = article['source']['name']
            print(f"Title: {title}\nDescription: {description}\nSource: {source}\n")
    
    except Exception as e:
        print("An error occurred:", str(e))

#Example usage:
#search_news_by_topic("technology")

# %%
import difflib
import re
import json

def load_intents(file_path):
    with open(file_path, 'r') as file:
        intents_data = json.load(file)
    return intents_data['intents']
"""
def detect_intent(user_input, intents, similarity_threshold=0.7):
    for intent in intents:
        for pattern in intent['patterns']:
            similarity_score = difflib.SequenceMatcher(None, pattern.lower(), user_input.lower()).ratio()
            if similarity_score >= similarity_threshold:
                return intent['tag']
    return None

def detect_intent(user_input, intents):
    intent, topic = None, None
    for intent_data in intents:
        for pattern in intent_data['patterns']:
            regex_pattern = re.compile(pattern, re.IGNORECASE)
            match = regex_pattern.match(user_input)
            if match:
                # Extract the topic from the user input
                topic = user_input.replace(match.group(0), '').strip()
                intent = intent_data['tag']
                print("Detected intent:", intent)
                print("Extracted topic:", topic)
                return intent, topic
    
    # If no intent is detected, return (None, None)
    print("Intent not recognized.")
    return intent, topic
"""
import difflib
import re

def detect_intent(user_input, intents, similarity_threshold=0.55):
    intent, topic = None, None
    for intent_data in intents:
        for pattern in intent_data['patterns']:
            regex_pattern = re.compile(pattern, re.IGNORECASE)
            match = regex_pattern.match(user_input)
            if match:
                # Extract the topic from the user input
                topic = user_input.replace(match.group(0), '').strip()
                intent = intent_data['tag']
                print("Detected intent:", intent)
                print("Extracted topic:", topic)
                return intent, topic
    
    # If no exact match is found, try similarity scoring
    max_similarity_score = 0
    for intent_data in intents:
        for pattern in intent_data['patterns']:
            similarity_score = difflib.SequenceMatcher(None, pattern.lower(), user_input.lower()).ratio()
            if similarity_score >= similarity_threshold and similarity_score > max_similarity_score:
                # Extract the topic from the user input
                topic = user_input.replace(pattern, '').strip()
                intent = intent_data['tag']
                max_similarity_score = similarity_score
    if intent:
        print("Detected intent (similarity score):", intent)
        print("Extracted topic (similarity score):", topic)
        return intent, topic
    
    # If no intent is detected, return (None, None)
    if not intent and not topic:
        print("Intent not recognized.")
    return intent, topic
"""
def main():
    intents = load_intents('/Users/mohitsingh/classeswinter24/ai/jupyter/intents2.json')
    print("Welcome to the News Chatbot!")
    while True:
        user_input = input("You: ")
        if user_input.lower() == "0":
            print("Goodbye!")
            break
        intent = detect_intent(user_input, intents)
        if intent:
            print("Detected intent:", intent)
            if intent == 'get_headlines':
                get_headlines()  # Call the function for the 'get_headlines' intent
            elif intent == "search_by_topic":
                # Extract topic from user input
                topic = extract_topic(user_input)
                response = search_news_by_topic(topic)
            else:
                print("Intent not recognized.")
        else:
            print("Intent not recognized.")
"""
def main():
    intents = load_intents('intents2.json')
    print("Welcome to the News Chatbot!")
    while True:
        user_input = input("You: ")
        if user_input.lower() == "0":
            print("Goodbye!")
            break
        intent, topic = detect_intent(user_input, intents)
        if intent:
            print("Detected intent:", intent)
            if intent == 'get_headlines':
                get_headlines()  # Call the function for the 'get_headlines' intent
            elif intent == "search_by_topic":
                response = search_news_by_topic(topic)
            else:
                print("Intent not recognized.")
        else:
            print("Intent not recognized.")

if __name__ == "__main__":
    main()
# Out:
# Welcome to the News Chatbot!
# You:  find news about tesla
# Detected intent: search_by_topic
# Extracted topic: tesla
# Detected intent: search_by_topic
# Title: Tesla will unveil a robotaxi on April 8, according to Musk
# Description: Tesla is introducing a robotaxi on August 8, Elon Musk has announced on X a few hours after Reuters published a report that the automaker is scrapping its plans to produce a low-cost EV. Reuters also said that Musk's directive was to "go all in" on robotaxis …
# Source: Yahoo Entertainment
#
# Title: Tesla sees EV deliveries drop year-over-year for the first time since 2020
# Description: Tesla
#  has revealed how many vehicles it delivered in the first three months of 2024 and the figures dropped significantly from both the previous quarter and the same period in 2023
# . The company handed over
#  386,810 EVs during the period.
# That's down 20 p…
# Source: Yahoo Entertainment
#
# Title: Tesla Is Going All In on Robotaxis—Buckle Up
# Description: Autonomous vehicle tech has proven tricky for even the most sophisticated tech developers. But Tesla seems to be staking its future on it.
# Source: Wired
#
# Title: Rivian owners now have access to Tesla Superchargers
# Description: Rivian customers now have access to over 15,000 Tesla Supercharger stations in the US. The company is starting to send adapters to its customers so they can use the stations.
# Source: The Verge
#
# Title: Tesla is settling with the family of the Apple engineer who died in an Autopilot crash
# Description: Tesla was scheduled to appear in court to defend its Autopilot system against a claim of wrongful death — but it looks it’ll pay the family of Wei “Walter” Huang instead.
# Source: The Verge
